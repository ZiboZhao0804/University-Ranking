# %% [markdown]
# Import Dependencies

# %%
# import pandas as pd

# %%
# data_df = pd.read_csv('../Data/data.csv')
# niche_df = data_df[['name','rating','location','niche_grade','acceptance_rate (%)','net_price ($)','SAT_range',
#                    'SAT_low','SAT_high','SAT_average']].groupby('niche_grade')
# niche_df.head()
# Out:
#                                                  name  rating  \
# 0               Massachusetts Institute of Technology       1
# 1                                  Harvard University       2
# 2                                 Stanford University       3
# 3                                     Yale University       4
# 4                                Princeton University       5
# 88                          The Ohio State University      89
# 89                              Mount Holyoke College      90
# 90                   University of California - Davis      91
# 91                             Santa Clara University      92
# 92                           Colorado School of Mines      93
# 280                       Pacific Lutheran University     281
# 281           The University of Alabama in Huntsville     282
# 282               University of Wisconsin - La Crosse     283
# 283                                      Bard College     284
# ...

# %%
# data_df.head()
# Out:
#                                     name  rating       location niche_grade  \
# 0  Massachusetts Institute of Technology       1  Cambridge, MA          A+
# 1                     Harvard University       2  Cambridge, MA          A+
# 2                    Stanford University       3   Stanford, CA          A+
# 3                        Yale University       4  New Haven, CT          A+
# 4                   Princeton University       5  Princeton, NJ          A+
#
#    acceptance_rate (%)  net_price ($)  SAT_range       city state  SAT_low  \
# 0                    7        20465.0  1510-1570  Cambridge    MA   1510.0
# 1                    5        18030.0  1460-1570  Cambridge    MA   1460.0
# 2                    4        16779.0  1440-1570   Stanford    CA   1440.0
# 3                    6        18073.0  1460-1570  New Haven    CT   1460.0
# 4                    6        18712.0  1460-1570  Princeton    NJ   1460.0
#
# ...

# %%
# niche_df.isnull().values.any()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-0f5ce1fc3c22> in <module>
# ----> 1 niche_df.isnull().values.any()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'isnull'

# %%
# niche_df.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-e45ecb5045d7> in <module>
# ----> 1 niche_df.columns
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'columns'

# %%
# state_df.to_json("Data/boxplot.json", orient = "records")
